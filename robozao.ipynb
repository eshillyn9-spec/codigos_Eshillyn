# %%
# estopu importando o puautogui e apelidando ele de aut
import pyautogui as aut

#pressiono a tecla de atalho win +r
aut.hotkey("win","r")
#escrever notepad
aut.write("chrome", interval = 0.7)
#espera 1 segundo
aut.sleep(1)
#aperta o enter
aut.press("enter")
aut.sleep(1)
aut.moveTo(943,612)
aut.click()
aut.sleep(1)
aut.moveTo(330,55)
aut.click()
aut.sleep(1)
aut.write("https://youtu.be/kivUsDGWojU?si=Q81qRXoPeJJV3i7Y" , interval = 0.03)
aut.press("Enter")

# %%
# estopu importando o puautogui e apelidando ele de aut
import pyautogui as aut

#pressiono a tecla de atalho win +r
aut.press("win")
aut.sleep(1)
aut.write("calculadora" , interval = 0.03)
aut.press("Enter")
aut.sleep(1)
aut.moveTo(103,427)
aut.click()
aut.sleep(1)
aut.moveTo(329,488)
aut.click()
aut.sleep(1)
aut.moveTo(251,379)
aut.click()
aut.sleep(1)
aut.moveTo(325,539)
aut.click()

# %%
# estopu importando o puautogui e apelidando ele de aut
import pyautogui as aut

#pressiono a tecla de atalho win +r
aut.hotkey("win","r")
#escrever notepad
aut.write("chrome", interval = 0.7)
#espera 1 segundo
aut.sleep(1)
#aperta o enter
aut.press("enter")
aut.sleep(1)
aut.moveTo(774,572)
aut.click()
aut.sleep(1)
aut.moveTo(1833,143)
aut.click()
aut.sleep(1)
aut.moveTo(1624,355)
aut.click()
aut.sleep(10)
aut.moveTo(784,209)
aut.click()
aut.sleep(5)
aut.moveTo(1242,600)
aut.click()
aut.sleep(7)
aut.moveTo(1531,245)
aut.click()
aut.sleep(6)
aut.moveTo(960,549)
aut.click()
aut.sleep(5)
aut.moveTo(950,1058)
aut.click()
aut.sleep(1)
aut.moveTo(1100,388)
aut.click()
aut.sleep(1)
aut.moveTo(1377,278)
aut.rightClick()
aut.sleep(1)
aut.moveTo(1368,313)
aut.click()
aut.sleep(1)
aut.moveTo(1096,358)
aut.click()
aut.sleep(1)
aut.moveTo(1295,250)
aut.doubleClick()
aut.sleep(1)
aut.moveTo()
aut.click()
aut.sleep(1)
aut.hotkey("ctrl","v")
# aut.moveTo()
# aut.click()
# aut.sleep(1)
# aut.moveTo()
# aut.click()
# aut.sleep(1)
# aut.moveTo()
# aut.click()
# aut.sleep(1)
# aut.moveTo()
# aut.click()
# aut.sleep(1)
# aut.moveTo()
# aut.click()
# aut.sleep(1)

# %%
#pega a informação do mouse
aut.mouseInfo()
